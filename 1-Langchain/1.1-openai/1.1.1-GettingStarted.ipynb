# %% [markdown]
# #### Getting started With Langchain And Open AI
#
# In this quickstart we'll see how to:
#
# - Get setup with LangChain, LangSmith and LangServe
# - Use the most basic and common components of LangChain: prompt templates, models, and output parsers.
# - Build a simple application with LangChain
# - Trace your application with LangSmith
# - Serve your application with LangServe

# %%
import os
from dotenv import load_dotenv
load_dotenv()

os.environ['OPENAI_API_KEY']=os.getenv("OPENAI_API_KEY")
## Langsmith Tracking
os.environ["LANGCHAIN_API_KEY"]=os.getenv("LANGCHAIN_API_KEY")
os.environ["LANGCHAIN_TRACING_V2"]="true"
os.environ["LANGCHAIN_PROJECT"]=os.getenv("LANGCHAIN_PROJECT")

# %%
from langchain_openai import ChatOpenAI
llm=ChatOpenAI(model="gpt-4o")
print(llm)
# Out:
# metadata={'lc_versions': {'langchain-core': '1.6.3', 'langchain': '1.4.0', 'langchain-openai': '1.6.2'}} profile={'name': 'GPT-4o', 'release_date': '2024-05-13', 'last_updated': '2024-08-06', 'open_weights': False, 'max_input_tokens': 128000, 'max_output_tokens': 16384, 'text_inputs': True, 'image_inputs': True, 'audio_inputs': False, 'pdf_inputs': True, 'video_inputs': False, 'text_outputs': True, 'image_outputs': False, 'audio_outputs': False, 'video_outputs': False, 'reasoning_output': False, 'tool_calling': True, 'structured_output': True, 'attachment': True, 'temperature': True, 'image_url_inputs': True, 'pdf_tool_message': True, 'image_tool_message': True, 'tool_choice': True, 'tool_call_streaming': True} client=<openai.resources.chat.completions.completions.Completions object at 0x10ff0a080> async_client=<openai.resources.chat.completions.completions.AsyncCompletions object at 0x110a7e980> root_client=<openai.OpenAI object at 0x10ff09ff0> root_async_client=<openai.AsyncOpenAI object at 0x110a7e950> model_name='gpt-4o' model_kwargs={} openai_api_key=SecretStr('**********') stream_usage=True stream_chunk_timeout=120.0

# %%
## Input and get response form LLM

result=llm.invoke("What is generative AI?")

# %%
print(result)
# Out:
# content='Generative AI refers to a subset of artificial intelligence that focuses on creating new content or data that mimics existing patterns. It leverages complex models, often based on neural networks such as Generative Adversarial Networks (GANs) or Variational Autoencoders (VAEs), to generate data that could be in the form of text, images, audio, and more.\n\nKey characteristics of generative AI include:\n\n1. **Creativity and Innovation**: Unlike traditional AI, which focuses on classification or prediction based on existing data, generative AI creates new outputs that are not explicitly part of the input data. This makes it useful in fields such as art, music, writing, and design.\n\n2. **Deep Learning Techniques**: Generative AI typically employs deep learning algorithms. GANs, for example, consist of two neural networks, a generator and a discriminator, that work against each other to improve the quality of generated data.\n\n3. **Applications**: Generative AI has a wide range of applications, including:\n   - **Art and Design**: Creating original artworks, designs, or animations.\n   - **Text Generation**: Producing written content, such as articles, poetry, or even code.\n   - **Data Augmentation**: Enhancing training datasets by generating additional data samples.\n   - **Entertainment**: Generating music, video game levels, or virtual characters.\n   - **Healthcare**: Synthesizing medical images for research and training purposes.\n\n4. **Challenges**: While powerful, generative AI poses challenges, such as ensuring the ethical use of generated content, managing biases that might be inherited from the training data, and preventing misuse such as deep fakes.\n\nOverall, generative AI holds great potential in advancing creativity and technological innovation, but it also requires careful consideration of ethical and societal impacts.' additional_kwargs={'refusal': None} response_metadata={'token_usage': {'completion_tokens': 371, 'prompt_tokens': 13, 'total_tokens': 384, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0, 'text_tokens': None}, 'prompt_tokens_details': {'audio_tokens': 0, 'cache_write_tokens': None, 'cached_tokens': 0, 'image_tokens': None, 'text_tokens': None}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_10b51c0fa7', 'id': 'chatcmpl-EPISeQQ5lFSaBgfvMfoX0zrrxypIW', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None} id='lc_run--01a0b24e-4a61-7ab2-bc7a-38a8668d37ed-0' tool_calls=[] invalid_tool_calls=[] usage_metadata={'input_tokens': 13, 'output_tokens': 371, 'total_tokens': 384, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}

# %%
### Chatprompt Template
from langchain_core.prompts import ChatPromptTemplate

prompt=ChatPromptTemplate.from_messages(
    [
        ("system","You are an expert AI Engineer. Provide me answers based on the questions"),
        ("user","{input}")
    ]

)
prompt
# Out:
# ChatPromptTemplate(input_variables=['input'], input_types={}, partial_variables={}, messages=[SystemMessagePromptTemplate(prompt=PromptTemplate(input_variables=[], input_types={}, partial_variables={}, template='You are an expert AI Engineer. Provide me answers based on the questions'), additional_kwargs={}), HumanMessagePromptTemplate(prompt=PromptTemplate(input_variables=['input'], input_types={}, partial_variables={}, template='{input}'), additional_kwargs={})])

# %%
## chain 
chain=prompt|llm

response=chain.invoke({"input":"Can you tell me about Langsmith?"})
print(response)
# Out:
# content='Langsmith is a tool designed to enhance the development, testing, and monitoring of applications constructed with large language models (LLMs) and chains. Developed by the creators of LangChain, Langsmith provides a suite of features that streamline the ability to debug and fine-tune language model-driven applications effectively.\n\nSome of its key features include:\n\n1. **Tracing and Logging:** It allows developers to trace and log how data flows through their applications, making it easier to identify where errors occur or where performance bottlenecks arise.\n\n2. **Error Analysis and Debugging:** The platform provides tools to analyze errors and debug applications, which are particularly useful when dealing with complex chain logic or when interactions between multiple models cause issues.\n\n3. **Performance Monitoring:** Langsmith offers insights into performance metrics, helping developers to optimize their applications for speed and efficiency.\n\n4. **User-Friendly Interface:** It provides a user-friendly interface for visualizing and understanding how data and prompts are processed by LLMs and chains.\n\n5. **Integration with LangChain:** As a product born from the LangChain ecosystem, Langsmith seamlessly integrates with applications built using LangChain, providing a coherent workflow from development to deployment.\n\nOverall, Langsmith is a comprehensive tool that supports developers in building robust, efficient, and reliable applications powered by language models.' additional_kwargs={'refusal': None} response_metadata={'token_usage': {'completion_tokens': 262, 'prompt_tokens': 33, 'total_tokens': 295, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0, 'text_tokens': None}, 'prompt_tokens_details': {'audio_tokens': 0, 'cache_write_tokens': None, 'cached_tokens': 0, 'image_tokens': None, 'text_tokens': None}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_5f6d02d065', 'id': 'chatcmpl-EPISipPuINOMu6YNH2AmJYVm6ePZp', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None} id='lc_run--01a0b24e-6011-7450-80a8-0b84ce55eece-0' tool_calls=[] invalid_tool_calls=[] usage_metadata={'input_tokens': 33, 'output_tokens': 262, 'total_tokens': 295, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}

# %%
type(response)
# Out:
# langchain_core.messages.ai.AIMessage

# %%
## stroutput Parser

from langchain_core.output_parsers import StrOutputParser
output_parser=StrOutputParser()
chain=prompt|llm|output_parser

response=chain.invoke({"input":"Can you tell me about Langsmith?"})
print(response)
# Out:
# Langsmith is a tool associated with LangChain, aimed at helping developers and engineers build and optimize applications that utilize large language models (LLMs). It provides a suite of features designed to streamline the development process, including robust tracing and debugging tools to better understand how language models interact within applications. Langsmith also offers evaluation functionalities, allowing users to assess the performance of their models and fine-tune them for improved results. These capabilities make it a valuable resource for anyone looking to efficiently develop and refine applications that leverage the power of LLMs.
